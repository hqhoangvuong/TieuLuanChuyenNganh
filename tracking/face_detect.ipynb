# %%
import insightface
import cv2
import numpy as np
from matplotlib import pyplot as plt
import math
import os
from imutils.video import VideoStream
from imutils.video import FPS
import imutils

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 100

# %%
color = (0, 0, 255)
ctx_id = 0

# %%
model = insightface.app.FaceAnalysis()
model.prepare(ctx_id = ctx_id, nms=0.4)
# Out:
# [32, 16, 8] {'32': {'SCALES': (32, 16), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}, '16': {'SCALES': (8, 4), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}, '8': {'SCALES': (2, 1), 'BASE_SIZE': 16, 'RATIOS': (1.0,), 'ALLOWED_BORDER': 9999}}
# use_landmarks True

# %%
img = cv2.imread('first_frame.png')

# %%
faces = model.get(img)

# %%
face = faces[0]

# %%
bbox = face.bbox.astype(np.int).flatten()

cv2.rectangle(img, (bbox[0], bbox[1]), (bbox[2], bbox[3]), (255, 0, 0), 3)
cv2.rectangle(img, (bbox[0] - 10, bbox[1] - 10), (bbox[2] + 10, bbox[3] + 10), (0, 255, 0), 3)
plt.imshow(img)

# %%
print(bbox)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-53e77a9d99fb> in <module>
# ----> 1 print(bbox)
#
# NameError: name 'bbox' is not defined

# %%
def area(a, b):  
    dx = min(a[2], b[2]) - max(a[0], b[0])
    dy = min(a[3], b[3]) - max(a[1], b[1])
    print(a, b)
    print(dx, dy)
    if (dx >= 0) and (dy >= 0):
        return dx * dy

bbox_track = [bbox[0] - 10, bbox[1] - 10, bbox[2] + 10, bbox[3] + 10]

print (area([1,2,3,4], bbox))
# Out:
# [1, 2, 3, 4] [1275  198 1309  238]
# -1272 -194
# None
